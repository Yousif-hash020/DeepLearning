# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
document = [
    "I love pizza",
    "pizza is the best",
    "i love pasta",
    "pasta is the best",
    "i love pizza pasta"
]

# %%
vectorize = TfidfVectorizer()

# %%
X =vectorize.fit_transform(document)

# %%
print("vocabulary", vectorize.get_feature_names_out())
print("\n BOW matix :\n", X.toarray())
# Out:
# vocabulary ['best' 'is' 'love' 'pasta' 'pizza' 'the']
#
#  BOW matix :
#  [[0.         0.         0.70710678 0.         0.70710678 0.        ]
#  [0.52064623 0.52064623 0.         0.         0.43218341 0.52064623]
#  [0.         0.         0.70710678 0.70710678 0.         0.        ]
#  [0.52064623 0.52064623 0.         0.43218341 0.         0.52064623]
#  [0.         0.         0.57735027 0.57735027 0.57735027 0.        ]]
